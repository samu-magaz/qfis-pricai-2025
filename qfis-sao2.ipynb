# %% [markdown]
# ## Requirements
#
# To use this library, ```python~=3.12``` is recommended, and its environment must have both ```numpy``` and ```qiskit>=1.0``` installed.

# %% [markdown]
# ## Initialize notebook
#
# We import the functions provided for the building and running of the quantum circuit for the QFIS of the $SaO_2$ problem.

# %%
from src.qfis import get_quantum_circuit, run_quantum_circuit

# %% [markdown]
# ## Build the circuit
#
# We can build the circuit and plot it using Qiskit's ```draw()``` method.

# %%
get_quantum_circuit([5,5]).draw(output='mpl')

# %% [markdown]
# ## Run the circuit
#
# With the library, we too can run the circuit for any given crisp inputs.

# %%
crisp_output = run_quantum_circuit([42,64])
print(f'Event likeliness: {crisp_output}')
# Out:
# Event likeliness: 0.7
